# %%
import matplotlib.pyplot as plt

# %%
train_plx = [79.8031036153574,
             20.987159780255627,
             12.767893267364038,
             9.963588444807977,
             8.477259182067867,
             7.57999423615244,
             6.9597412483670675,
             6.390854498027496,
             6.0238067083249325,
             5.649736965896014]
dev_plx = [34.28326320493816,
           20.572235938760652,
           15.59095280537022,
           13.853058114140033,
           13.32918883754414,
           12.687491964036203,
           12.33453376138732,
           12.248003378833143,
           12.240018796136168,
           12.101658614604574]
dev_bleu = [0.2092209939735702,
            0.30080598109021317,
            0.35089677119565366,
            0.3720451575432418,
            0.3833687342688832,
            0.39190008928098846,
            0.40090988929889565,
            0.39509114633181475,
            0.40209582624093737,
            0.4083651726705043]

# %%
plt.rcParams['font.family'] = "serif"

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(range(len(dev_bleu)),  dev_bleu, 'r', lw = .5)
ax.plot(range(len(dev_bleu)), dev_bleu, 'r^', label='Dev Bleu Score')
ax.legend()

fig.savefig('../results/bleu.png')

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(range(10),  dev_plx, 'r', lw = .5)
ax.plot(range(10), dev_plx, 'r^', label='Dev Perplexity Score')
ax.plot(range(10),  train_plx, 'b', lw = .5)
ax.plot(range(10), train_plx, 'bo', label='Dev Perplexity Score')

ax.legend()

fig.savefig('../results/pplx.png')
